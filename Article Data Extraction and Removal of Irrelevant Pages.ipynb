# %% [markdown]
# # Article Data Extraction and Removal of Irrelevant Pages
# Author: Sean Flannery [sflanner@purdue.edu](sflanner@purdue.edu)
#
# Last Updated: June 14th, 2019
#
# This notebook was developed with the intent of satisfying local data parsing needs for work with
# Professor Daisuke Kihara [dkihara@purdue.edu](dkihara@purdue.edu).
# ### Description
# We are interested in grabbing the Abstract, Author, & Introduction Data from a given set of article html files (assumed to have been already downloaded).
#
# We have provided a folder `articles` that contains the respective **years** and **\*.html** files where we may find pertinent articles.
#
# **Libraries Needed:**
# [pandas](https://pandas.pydata.org/pandas-docs/stable/install.html),
# [numpy](https://www.numpy.org),
# [tqdm](https://github.com/tqdm/tqdm),
# [bs4](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)

# %%
import pandas as pd
import numpy as np
np.random.seed(42)
import re
import os
import time
import random
random.seed(42)

from bs4 import BeautifulSoup, SoupStrainer

from multiprocessing import Pool
from tqdm import tqdm_notebook as tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
nar_df = pd.read_csv('article-path-data.csv',
                     names = ['year','article-link', 'local-path', 'title', 'abstract', 'authors', 'introduction'],
                     skiprows=1)

# %%
nar_df.head()
# Out:
#    year                         article-link                local-path  title  \
# 0  2019  https://doi.org/10.1093/nar/gky1267  articles/2019/0-NAR.html    NaN
# 1  2019   https://doi.org/10.1093/nar/gky993  articles/2019/1-NAR.html    NaN
# 2  2019  https://doi.org/10.1093/nar/gky1124  articles/2019/2-NAR.html    NaN
# 3  2019  https://doi.org/10.1093/nar/gky1069  articles/2019/3-NAR.html    NaN
# 4  2019   https://doi.org/10.1093/nar/gky843  articles/2019/4-NAR.html    NaN
#
#    abstract  authors  introduction
# 0       NaN      NaN           NaN
# 1       NaN      NaN           NaN
# 2       NaN      NaN           NaN
# 3       NaN      NaN           NaN
# 4       NaN      NaN           NaN

# %% [markdown]
# Grab the title of the article.

# %%
def getTitle(filename):
    # Open html file for processing
    f = open(filename)
    soup = BeautifulSoup(f, 'html.parser')
    f.close()
    # Grab section of html named after the abstract
    tmp = str(soup.findAll("h1", {"class": "article-title-main"}))
    soup = BeautifulSoup(tmp, 'html.parser')
    # Clean up the text and store it in the result
    return soup.get_text(strip=True)[1:-1]

# %% [markdown]
# Grab all text from the section with class abstract.

# %%
def getAbstract(filename):
    # Open html file for processing
    f = open(filename)
    soup = BeautifulSoup(f, 'html.parser')
    f.close()
    # Grab section of html named after the abstract
    tmp = str(soup.findAll("section", {"class": "abstract"}))
    soup = BeautifulSoup(tmp, 'html.parser')
    # Clean up the text and store it in the result
    return soup.get_text(strip=True)[1:-1]

# %% [markdown]
# Grab the information inside the info card at the top of the webpage. There are 2 methods to use here

# %%
def getAuthor(filename):
    f = open(filename)
    soup = BeautifulSoup(f, 'html.parser')
    f.close()
    tmp = str(soup.findAll("div", {"class": "info-card-name"}))
    if len(tmp) == 0:
        tmp = soup.findAll("div", {"class": "meta-authors--limited"})
    if len(tmp) == 0:
        tmp = soup.findAll("div", {"class": "wi-authors"})
    soup = BeautifulSoup(str(tmp), 'html.parser')
    return soup.get_text(strip=True)[1:-1].split(',')

# %% [markdown]
# Grab the first `<h2>` html tag that indicates a section title on the page, confirm that it contains the words "introduction", and then return it!

# %%
def getIntroductionFromHeaders(filename):
    f = open(filename)
    soup = BeautifulSoup(f, 'html.parser')
    f.close()
    # Seek to the first header
    found = soup.findAll("h2", {"class": "section-title"})
    # Initially assume that neither intro nor the section after is found
    intro = None
    after = None
    # If we find only 1 header, it's likely just the acknowledgements
    if len(found) <= 1:
        return None
    else:
        found_intro = False
        for ent in found:
            if found_intro:
                after = ent
                break
            if 'introduction' in str(ent).lower():
                intro = ent
        # Start at the first paragraph containing h2
        intro = found[0]
        # End before the next h2 section (AKA the next section of text -- likely not introduction)
        after = found[1]
    
    resStr = ''
    # If we were not able to identify individual sections
    # just take anything in paragraph tags in the article body
    if intro is None or after is None:
        res['introduction'] = None
        return res
    else:      
        next_p = intro.find_next("p")
        last_p = after.find_previous_sibling("p")
        if last_p is None:
            return None
        last_p = last_p.get_text(strip=True)
        if last_p is None or next_p is None:
            return None
        while str(next_p.get_text(strip=True)) != str(last_p):
            tmpStr = str(next_p.get_text(strip=True))
            resStr += tmpStr + '\n'
            next_p = next_p.find_next("p")
        resStr += str(last_p)
    return resStr

# %% [markdown]
# We need to handle the results with no intro now with a deeper level of granularity. This method focuses on just grabbing as many `<p>` tags as possible.
#
# This also requires us to **define some number of paragraphs** to grab. We initially just grab up to 3 paragraphs.

# %%
PARAGRAPH_NUMBER = 3
def getIntroductionFromParagraphs(filename):
    abstract = getAbstract(filename)
    f = open(filename)
    soup = BeautifulSoup(f, 'html.parser')
    f.close()
    # Seek to the first header
    resStr = ''  
    content_blocks = soup.findAll("div", {"id": "ContentTab"})
    if content_blocks is None or len(content_blocks) == 0:
        return None
    content_block = content_blocks[0]
    soup = BeautifulSoup(str(content_block), 'html.parser')
    pars = soup.findAll("p")
    if len(pars) == 0:
        return None
    
    parCount = 0
    next_p = str(pars[parCount].get_text(strip=True))
    parCount += 1
    while not abstract in next_p and parCount < len(pars):
        next_p = str(pars[parCount].get_text(strip=True))
        parCount += 1
    counter = 0
    while next_p is not None and counter < PARAGRAPH_NUMBER and parCount < len(pars):
        counter = counter + 1
        next_p = str(pars[parCount].get_text(strip=True))
        parCount += 1 
        resStr += str(next_p + '\n')
    if resStr == '':
        return None
    else:
        return resStr

# %%
def getIntroduction(filename):
    res = getIntroductionFromHeaders(filename)
    if res is None or len(res) < 4:
        res = getIntroductionFromParagraphs(filename)
    return res

# %% [markdown]
# Define a function to grab a url's various page information.

# %%
def getWebPageData(urlID):
    res = dict()    
    res['urlID'] = urlID
    filename = str(nar_df.loc[urlID,'local-path'])
    ### Title 
    res['title'] = getTitle(filename)
    ### Abstract
    res['abstract'] = getAbstract(filename)
    ### Authors
    res['authors'] = getAuthor(filename)
    ### Introduction
    res['introduction'] = getIntroductionFromHeaders(filename)
    if res['introduction'] is None or len(res['introduction']) <=2:
        res['introduction'] = getIntroductionFromParagraphs(filename)
    return res

# %% [markdown]
# Generate several processes to do these processes concurrently.

# %%
req_list = []
entry_range = range(len(nar_df))
with Pool(8) as p:
    req_list = list(tqdm(p.imap(getWebPageData, entry_range), total=len(entry_range), leave=False))
# Out:
# HBox(children=(IntProgress(value=0, max=3149), HTML(value='')))

# %% [markdown]
# We are now going to transfer our returned results to the database.

# %%
# Quick fix for authors column so it accepts valid datatype
nar_df['authors'] = nar_df['authors'].astype(object)

for res in req_list:
    urlID = res['urlID']
    nar_df.loc[urlID, 'title'] = res['title']
    nar_df.loc[urlID, 'abstract'] = res['abstract']
    nar_df.at[urlID,'authors'] = res['authors']
    nar_df.loc[urlID, 'introduction'] = res['introduction']

# %% [markdown]
# **Let's store the original version of the nar database before we drop entries**

# %%
original_nar_df = nar_df.copy()
nar_df.to_csv('original-article-data.csv', index=False)
nar_df.head()
# Out:
#    year                         article-link                local-path  \
# 0  2019  https://doi.org/10.1093/nar/gky1267  articles/2019/0-NAR.html
# 1  2019   https://doi.org/10.1093/nar/gky993  articles/2019/1-NAR.html
# 2  2019  https://doi.org/10.1093/nar/gky1124  articles/2019/2-NAR.html
# 3  2019  https://doi.org/10.1093/nar/gky1069  articles/2019/3-NAR.html
# 4  2019   https://doi.org/10.1093/nar/gky843  articles/2019/4-NAR.html
#
#                                                title  \
# 0  The 26th annual Nucleic Acids Research databas...
# 1  Database Resources of the BIG Data Center in 2019
# 2  The European Bioinformatics Institute in 2018:...
# 3  Database resources of the National Center for ...
# 4  AmtDB: a database of ancient human mitochondri...
#
#                                             abstract  \
# 0  The 2019 Nucleic Acids Research (NAR) Database...
# 1  The BIG Data Center at Beijing Institute of Ge...
# 2  The European Bioinformatics Institute (https:/...
# 3  The National Center for Biotechnology Informat...
# 4  Ancient mitochondrial DNA is used for tracing ...
#
#                                              authors  \
# 0                [Daniel J Rigden, Xosé M Fernández]
# 1                          [BIG Data Center Members]
# 2  [Charles E Cook, Rodrigo Lopez, Oana Stroe, Gu...
# 3  [Eric W Sayers, Richa Agarwala, Evan E Bolton,...
# 4  [Edvard Ehler, Jiří Novotný, Anna Juras, Macie...
#
#                                         introduction
# 0  The Nucleic Acids Research (NAR) Database Issu...
# 1  The BIG Data Center (http://bigd.big.ac.cn) at...
# 2  A primary mission of EMBL-EBI is to collect, o...
# 3  The National Center for Biotechnology Informat...
# 4  Ancient DNA (aDNA) is a genetic material obtai...

# %% [markdown]
# Display Statistics!

# %%
no_abstracts = nar_df[nar_df.abstract.isna()]
no_intro = nar_df[nar_df.introduction.isna()]
has_intro = nar_df[nar_df.introduction.notna()]
        
print("No introduction %s/%s: %.2f%%" % (len(no_intro), len(nar_df), (100. * len(no_intro))/ len(nar_df)))
print("No abstracts %s/%s: %.2f%%" % (len(no_abstracts), len(nar_df), (100. * len(no_abstracts))/ len(nar_df)))
count = 0
for uid in has_intro.index:
    introStr = str(nar_df.loc[uid, 'introduction'])
    abstractStr = str(nar_df.loc[uid, 'abstract'])
    if abstractStr in introStr:
        count = count + 1
print("Intro contains abstract %s/%s: %.2f%%" % (count, len(has_intro), (100. * count / len(has_intro))))
# Out:
# No introduction 11/3149: 0.35%
# No abstracts 0/3149: 0.00%
# Intro contains abstract 18/3138: 0.57%

# %% [markdown]
# ### Data Cleaning
#
# We want to drop all unneeded pages based on title or filetype.
#
# Drop entries leading to a PDF file (likely a pdf saying "under development", but nevertheless unscrapable)
#
# We include a method to check if the downloaded file is a PDF.

# %%
def checkPDF(filename):
    f = open(filename)
    file_head = f.read(4)
    f.close()
    return "%PDF" == file_head

# %%
for index, row in nar_df.iterrows():
    # Remove all editorial, subscription pages
    if 'editorial' in row['title'].lower() or 'subscription' in row['title'].lower():
        nar_df.drop(index, inplace=True)
    # Drop all files that are just PDFs
    if checkPDF(row['local-path']):
        nar_df.drop(index, inplace=True)
    # Remove all database issues
    if 'database issue' in row['title'].lower():
        nar_df.drop(index, inplace=True)

# %%
no_abstracts = nar_df[nar_df.abstract.isna()]
no_intro = nar_df[nar_df.introduction.isna()]
has_intro = nar_df[nar_df.introduction.notna()]
        
print("No introduction %s/%s: %.2f%%" % (len(no_intro), len(nar_df), (100. * len(no_intro))/ len(nar_df)))
print("No abstracts %s/%s: %.2f%%" % (len(no_abstracts), len(nar_df), (100. * len(no_abstracts))/ len(nar_df)))
count = 0
for uid in nar_df.index:
    introStr = str(nar_df.loc[uid, 'introduction'])
    abstractStr = str(nar_df.loc[uid, 'abstract'])
    # Check if abstractStr isn't empty before seeing if its in the intro
    if abstractStr in introStr and len(abstractStr) > 0:
        count = count + 1
print("Intro contains abstract %s/%s: %.2f%%" % (count, len(has_intro), (100. * count / len(has_intro))))
# Out:
# No introduction 1/3113: 0.03%
# No abstracts 0/3113: 0.00%
# Intro contains abstract 0/3112: 0.00%

# %% [markdown]
# Drop undesirable attributes (those that don't have the data we need)

# %%
for uid in nar_df.index:
# Drop the undesired entries
    introStr = str(nar_df.loc[uid, 'introduction'])
    abstractStr = str(nar_df.loc[uid, 'abstract'])
    if len(abstractStr) == 0 or len(introStr) == 0:
        nar_df.drop(uid)

# %% [markdown]
# Here, we should **ensure we haven't dropped articles erroneously by spot-checking the articles we've dropped**.

# %%
difference = original_nar_df[~original_nar_df.index.isin(nar_df.index)]
print("Total dropped entries:", len(difference))
# Out:
# Total dropped entries: 36

# %% [markdown]
# We should run through these entries and see if there are any we ought to restore.

# %%
difference
# Out:
#       year                         article-link                   local-path  \
# 0     2019  https://doi.org/10.1093/nar/gky1267     articles/2019/0-NAR.html
# 31    2019  https://doi.org/10.1093/nar/gky1050    articles/2019/31-NAR.html
# 85    2019   https://doi.org/10.1093/nar/gky992    articles/2019/85-NAR.html
# 150   2018  https://doi.org/10.1093/nar/gkx1235   articles/2018/150-NAR.html
# 152   2018   https://doi.org/10.1093/nar/gkx897   articles/2018/152-NAR.html
# 157   2018  https://doi.org/10.1093/nar/gkx1097   articles/2018/157-NAR.html
# 179   2018   https://doi.org/10.1093/nar/gkx864   articles/2018/179-NAR.html
# 262   2018  https://doi.org/10.1093/nar/gkx1020   articles/2018/262-NAR.html
# 298   2018   https://doi.org/10.1093/nar/gkx892   articles/2018/298-NAR.html
# 300   2017  https://doi.org/10.1093/nar/gkw1188   articles/2017/300-NAR.html
# 450   2016  https://doi.org/10.1093/nar/gkv1356   articles/2016/450-NAR.html
# 600   2015  https://doi.org/10.1093/nar/gku1241   articles/2015/600-NAR.html
# 750   2014  https://doi.org/10.1093/nar/gks1388   articles/2014/750-NAR.html
# 751   2014  https://doi.org/10.1093/nar/gks1412   articles/2014/751-NAR.html
# 752   2014  https://doi.org/10.1093/nar/gks1436   articles/2014/752-NAR.html
# 753   2014  https://doi.org/10.1093/nar/gkt1282   articles/2014/753-NAR.html
# 900   2013  https://doi.org/10.1093/nar/gks1297   articles/2013/900-NAR.html
# 1050  2012  https://doi.org/10.1093/nar/gkr1196  articles/2012/1050-NAR.html
# 1201  2011  https://doi.org/10.1093/nar/gkq1331  articles/2011/1201-NAR.html
# 1202  2011  https://doi.org/10.1093/nar/gkq1332  articles/2011/1202-NAR.html
# 1317  2011  https://doi.org/10.1093/nar/gkq1243  articles/2011/1317-NAR.html
# 1350  2010  https://doi.org/10.1093/nar/gkp1077  articles/2010/1350-NAR.html
# 1485  2010  https://doi.org/10.1093/nar/gkp1212  articles/2010/1485-NAR.html
# 1487  2010  https://doi.org/10.1093/nar/gkp1213  articles/2010/1487-NAR.html
# 1488  2009   https://doi.org/10.1093/nar/gkn942  articles/2009/1488-NAR.html
# 1638  2008  https://doi.org/10.1093/nar/gkm1139  articles/2008/1638-NAR.html
# 1788  2007  https://doi.org/10.1093/nar/gkl1051  articles/2007/1788-NAR.html
# 1938  2006   https://doi.org/10.1093/nar/gkj150  articles/2006/1938-NAR.html
# 2088  2005   https://doi.org/10.1093/nar/gki133  articles/2005/2088-NAR.html
# 2089  2005   https://doi.org/10.1093/nar/gki134  articles/2005/2089-NAR.html
# 2227  2004   https://doi.org/10.1093/nar/gkh142  articles/2004/2227-NAR.html
# 2370  2003   https://doi.org/10.1093/nar/gkg173  articles/2003/2370-NAR.html
# 2501  2002   https://doi.org/10.1093/nar/30.1.0  articles/2002/2501-NAR.html
# 2615  2001   https://doi.org/10.1093/nar/29.1.0  articles/2001/2615-NAR.html
# 2713  2000   https://doi.org/10.1093/nar/28.1.0  articles/2000/2713-NAR.html
# 2829  1999   https://doi.org/10.1093/nar/27.1.i  articles/1999/2829-NAR.html
#
#                                                   title  \
# 0     The 26th annual Nucleic Acids Research databas...
# 31
# 85
# 150   The 2018Nucleic Acids Researchdatabase issue a...
# 152
# 157
# 179
# 262
# 298
# 300   The 24th annualNucleic Acids Researchdatabase ...
# 450   The 2016 database issue ofNucleic Acids Resear...
# 600   The 2015Nucleic Acids ResearchDatabase Issue a...
# 750   Nucleic Acids Research: Volume 42 Database Iss...
# 751            Nucleic Acids Research - Editorial Board
# 752                                       Subscriptions
# 753   The 2014Nucleic Acids ResearchDatabase Issue a...
# 900   The 2013Nucleic Acids ResearchDatabase Issue a...
# 1050  The 2012 Nucleic Acids Research Database Issue...
# 1201  Nucleic Acids Research: VOLUME 39 DATABASE ISS...
# 1202                                      Subscriptions
# 1317  The 2011Nucleic Acids ResearchDatabase Issue a...
# 1350  The 2010Nucleic Acids ResearchDatabase Issue a...
# 1485  Nucleic Acids Research: VOLUME 38 DATABASE ISS...
# 1487                                      Subscriptions
# 1488  Nucleic Acids Researchannual Database Issue an...
# 1638                                          Editorial
# 1788                                          EDITORIAL
# 1938                                          EDITORIAL
# 2088                                          Editorial
# 2089                                          Editorial
# 2227                                          EDITORIAL
# 2370                                          Editorial
# 2501                                          Editorial
# 2615                                          Editorial
# 2713                                          Editorial
# 2829                                          Editorial
#
#                                                abstract  \
# 0     The 2019 Nucleic Acids Research (NAR) Database...
# 31
# 85
# 150   The 2018Nucleic Acids ResearchDatabase Issue c...
# 152
# 157
# 179
# 262
# 298
# 300   This year's Database Issue ofNucleic Acids Res...
# 450   The 2016 Database Issue ofNucleic Acids Resear...
# 600   The 2015Nucleic Acids ResearchDatabase Issue c...
# 750
# 751
# 752
# 753   The 2014 Nucleic Acids Research Database Issue...
# 900   The 20th annual Database Issue ofNucleic Acids...
# 1050  The 19th annual Database Issue ofNucleic Acids...
# 1201
# 1202
# 1317  The current 18th Database Issue ofNucleic Acid...
# 1350  The current issue ofNucleic Acids Researchincl...
# 1485
# 1487
# 1488  The current issue ofNucleic Acids Researchincl...
# 1638
# 1788
# 1938
# 2088
# 2089
# 2227
# 2370
# 2501
# 2615
# 2713
# 2829
#
#                                                 authors  \
# 0                   [Daniel J Rigden, Xosé M Fernández]
# 31                                                   []
# 85                                                   []
# 150                 [Daniel J Rigden, Xosé M Fernández]
# 152                                                  []
# 157                                                  []
# 179                                                  []
# 262                                                  []
# 298                                                  []
# 300   [Michael Y Galperin, Xosé M Fernández-Suárez, ...
# 450   [Daniel J. Rigden, Xosé M. Fernández-Suárez, M...
# 600   [Michael Y. Galperin, Daniel J. Rigden, Xosé M...
# 750                                                  []
# 751                                                  []
# 752                                                  []
# 753   [Xosé M. Fernández-Suárez, Daniel J. Rigden, M...
# 900     [Xosé M. Fernández-Suárez, Michael Y. Galperin]
# 1050    [Michael Y. Galperin, Xosé M. Fernández-Suárez]
# 1201                                                 []
# 1202                                                 []
# 1317             [Michael Y. Galperin, Guy R. Cochrane]
# 1350             [Guy R. Cochrane, Michael Y. Galperin]
# 1485                                                 []
# 1487                                                 []
# 1488             [Michael Y. Galperin, Guy R. Cochrane]
# 1638                                     [Alex Bateman]
# 1788                                     [Alex Batemen]
# 1938                                     [Alex Bateman]
# 2088                                     [Alex Bateman]
# 2089       [Dov Greenbaum, Andrew Smith, Mark Gerstein]
# 2227                                                 []
# 2370                                                 []
# 2501                                                 []
# 2615                                                 []
# 2713                                                 []
# 2829                                                 []
#
#                                            introduction
# 0     The Nucleic Acids Research (NAR) Database Issu...
# 31                                                 None
# 85                                                 None
# 150   This 2018Nucleic Acids ResearchDatabase Issue ...
# 152                                                None
# 157                                                None
# 179                                                None
# 262                                                None
# 298                                                None
# 300   The current 2017Nucleic Acids ResearchDatabase...
# 450   The 2016Nucleic Acids ResearchDatabase Issue i...
# 600   The currentNucleic Acids Research(NAR) Databas...
# 750   ONLINE ISSN: 1362-4962\nwww.nar.oxfordjournals...
# 751   Senior Editors: K.R.Fox,Southampton, UK; foxna...
# 752   Annual Subscription Rate (Volume 42, 22 issues...
# 753   The 21st annual Nucleic Acids Research Databas...
# 900   This 1300-page virtual volume represents the 2...
# 1050  This current, 19th annual Database Issue ofNuc...
# 1201  online issn: 1362-4962\nwww.nar.oxfordjournals...
# 1202  Annual Subscription Rate (Volume 38, 22 issues...
# 1317  This current, 18th annual Database Issue ofNuc...
# 1350  This Database Issue ofNucleic Acids Research(N...
# 1485  \nNow Open Access\nNo barriers to access – all...
# 1487  Annual Subscription Rate (Volume 38, 22 issues...
# 1488  The 2009Nucleic Acids Research(NAR) annual Dat...
# 1638  Michael Galperin has continued to produce and ...
# 1788  Michael Galperin continues to produce and enla...
# 1938  Michael Galperin continues to produce and enla...
# 2088  Michael Galperin has produced the Molecular Bi...
# 2089  The significant growth of this annual over the...
# 2227  \nFor several years, Andy Baxevanis has been p...
# 2370  At a recent meeting of the Editorial Board ofN...
# 2501                                               None
# 2615                                               None
# 2713                                               None
# 2829  The deadlines for submission of articles inten...

# %% [markdown]
# All of these appear to be either editorials, database editions (which just describes the database for that year), or a subscription page. It seems reasonable that they ought to be dropped.

# %%
nar_df.to_csv('complete-article-data.csv', index=False)
